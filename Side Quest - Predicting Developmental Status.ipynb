# %% [markdown]
# # EXTRA EXPLORATION: Model to Predict Development Status of Countries

# %%
import numpy as np
import pandas as pd
import seaborn as sb
import matplotlib.pyplot as plt
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn.metrics import confusion_matrix
from sklearn.tree import plot_tree
from sklearn.linear_model import LinearRegression
from sklearn.model_selection import train_test_split #helps split data evenly and randomly
from sklearn.metrics import mean_squared_error, mean_absolute_error
from sklearn import preprocessing 
sb.set()

pd.options.display.max_rows = 999

# %%
life_filled=pd.read_csv("dataset/life_filled.csv")
sb.scatterplot(x= life_filled["LIFE_EXPECTANCY"], y= life_filled["LIFE_EXPECTANCY"] , hue=life_filled["STATUS"])
# Out:
# <AxesSubplot:xlabel='LIFE_EXPECTANCY', ylabel='LIFE_EXPECTANCY'>

# %% [markdown]
# As we can see here from a graph in Exploratory Data Analysis.ipynb, Developed countries are expected to have a **greater** life expectancy compared to developing countries, hence we will see how the other features (including Life Expectancy) are able to predict and influence the result of a countries devolopment status.

# %% [markdown]
# ## Prediction using a Classification Decision Tree

# %%
lifeTransform =  pd.read_csv("dataset/life_transform.csv")
lifeTransform.drop(columns=lifeTransform.columns[0],axis=1,inplace=True)
lifeTransform
# Out:
#           COUNTRY  STATUS    YEAR  LIFE_EXPECTANCY  ADULT_MORTALITY  \
# 0     Afghanistan       1  2015.0         0.294686         0.802268
# 1     Afghanistan       1  2014.0         0.187396         0.813152
# 2     Afghanistan       1  2013.0         0.187396         0.809070
# 3     Afghanistan       1  2012.0         0.180763         0.814512
# 4     Afghanistan       1  2011.0         0.175788         0.818594
# ...           ...     ...     ...              ...              ...
# 2933     Zimbabwe       1  2004.0         0.046784         1.000000
# 2934     Zimbabwe       1  2003.0         0.047953         0.997757
# 2935     Zimbabwe       1  2002.0         0.049708         0.248889
# 2936     Zimbabwe       1  2001.0         0.052632         0.989627
# 2937     Zimbabwe       1  2000.0         0.056725         0.983740
#
#       INFANT_DEATHS   ALCOHOL  PERCENTAGE_EXPENDITURE  HEPATITIS_B   MEASLES  \
# 0          0.606280 -1.540089               -0.653537     0.317298  0.806913
# 1          0.611111 -1.540089               -0.641558     0.293245  0.766886
# 2          0.615942 -1.540089               -0.643161     0.309280  0.749863
# 3          0.623188 -1.540089               -0.617785     0.333333  0.883365
# 4          0.628019 -1.540089               -1.506529     0.340278  0.888946
# ...             ...       ...                     ...          ...       ...
# 2933       0.484848  0.149101                1.081648     0.340278  0.547009
# 2934       0.479798  0.088457                1.061102     0.018072  0.799610
# 2935       0.474747  0.162786               -2.312958     0.375000  0.715266
# 2936       0.474747 -0.554276               -2.312958     0.395833  0.777046
# 2937       0.469697 -0.569376                0.536294     0.416667  0.822316
#
#       ...  UNDER_FIVE_DEATHS     POLIO  TOTAL_EXPENDITURE  DIPHTHERIA  \
# 0     ...           0.616162  0.006410           0.562634    0.171717
# 1     ...           0.621212  0.127778           0.567017    0.156566
# 2     ...           0.626263  0.150000           0.556038    0.166667
# 3     ...           0.632997  0.177778           0.639925    0.181818
# 4     ...           0.639731  0.183333           0.497836    0.186869
# ...   ...                ...       ...                ...         ...
# 2933  ...           0.534188  0.177778           0.321024    0.171717
# 2934  ...           0.529915  0.008547           0.161034    0.186869
# 2935  ...           0.525641  0.211111           0.163773    0.202020
# 2936  ...           0.521368  0.233333           0.059581    0.222222
# 2937  ...           0.521368  0.255556           0.313477    0.255556
#
#       HIV/AIDS       GDP  POPULATION  THINNESS_5_to_19_YEARS  \
# 0     0.000000 -0.765913    0.695802                1.863475
# 1     0.000000 -0.745047   -0.642920                1.881842
# 2     0.000000 -0.731598    0.674292                1.896363
# 3     0.000000 -0.705787   -0.011252                1.914304
# 4     0.000000 -1.725140   -0.073218                1.932018
# ...        ...       ...         ...                     ...
# 2933  0.959553 -0.876123    0.368261                1.109933
# 2934  0.966928 -0.877103    0.364611                1.166410
# 2935  0.974304 -1.768514   -0.857872               -0.981848
# 2936  0.979776 -0.793556    0.357704               -0.744249
# 2937  0.983107 -0.794540    0.353934                1.311940
#
#       INCOME_COMPOSITION_OF_RESOURCES  SCHOOLING
# 0                            0.215278       10.1
# 1                            0.211111       10.0
# 2                            0.202778        9.9
# 3                            0.193056        9.8
# 4                            0.180556        9.5
# ...                               ...        ...
# 2933                         0.115278        9.2
# 2934                         0.130556        9.5
# 2935                         0.143056       10.0
# 2936                         0.143056        9.8
# 2937                         0.152778        9.8
#
# [2938 rows x 21 columns]

# %%
lifeTransform.describe()
# Out:
#             STATUS         YEAR  LIFE_EXPECTANCY  ADULT_MORTALITY  \
# count  2938.000000  2938.000000      2938.000000      2938.000000
# mean      0.825732  2007.518720         0.501309         0.497070
# std       0.379405     4.613841         0.278344         0.280640
# min       0.000000  2000.000000         0.000000         0.000000
# 25%       1.000000  2004.000000         0.249396         0.253333
# 50%       1.000000  2008.000000         0.522222         0.495726
# 75%       1.000000  2012.000000         0.742690         0.744048
# max       1.000000  2015.000000         1.000000         1.000000
#
#        INFANT_DEATHS       ALCOHOL  PERCENTAGE_EXPENDITURE  HEPATITIS_B  \
# count    2938.000000  2.938000e+03            2.938000e+03  2938.000000
# mean        0.498657 -1.876572e-16           -7.742842e-17     0.506461
# std         0.272273  1.000170e+00            1.000170e+00     0.295571
# min         0.000000 -1.540089e+00           -2.312958e+00     0.000000
# 25%         0.244444 -8.247969e-01           -7.858454e-01     0.245138
# 50%         0.489899  1.080217e-01           -6.462024e-02     0.500000
# 75%         0.766700  7.882520e-01            9.911980e-01     0.777778
# max         1.000000  2.393661e+00            1.623804e+00     1.000000
#
#            MEASLES          BMI  UNDER_FIVE_DEATHS        POLIO  \
# count  2938.000000  2938.000000        2938.000000  2938.000000
# mean      0.431738    38.790629           0.484631     0.509762
# std       0.340305    20.485912           0.295749     0.302967
# min       0.000000     1.000000           0.000000     0.000000
# 25%       0.000000    19.400000           0.230769     0.244444
# 50%       0.487179    43.900000           0.500000     0.518519
# 75%       0.730711    56.400000           0.767688     0.777778
# max       1.000000   116.135422           1.000000     1.000000
#
#        TOTAL_EXPENDITURE   DIPHTHERIA     HIV/AIDS           GDP  \
# count       2.938000e+03  2938.000000  2938.000000  2.938000e+03
# mean        4.402348e-17     0.505652     0.308969 -4.586755e-16
# std         1.000170e+00     0.298637     0.389081  1.000170e+00
# min        -3.762931e+00     0.000000     0.000000 -3.073607e+00
# 25%        -5.484182e-01     0.255556     0.000000 -7.687574e-01
# 50%        -2.295318e-03     0.518519     0.000000 -2.444449e-02
# 75%         5.692044e-01     0.777778     0.736111  8.016743e-01
# max         2.871616e+00     1.000000     1.000000  1.746533e+00
#
#          POPULATION  THINNESS_5_to_19_YEARS  INCOME_COMPOSITION_OF_RESOURCES  \
# count  2.938000e+03            2.938000e+03                      2938.000000
# mean   1.053540e-16           -2.648966e-16                         0.498775
# std    1.000170e+00            1.000170e+00                         0.284977
# min   -2.426608e+00           -2.172591e+00                         0.000000
# 25%   -6.717270e-01           -7.715521e-01                         0.242630
# 50%   -8.349672e-02           -2.535882e-02                         0.508547
# 75%    6.764212e-01            8.014589e-01                         0.748889
# max    2.210668e+00            2.500756e+00                         1.000000
#
#          SCHOOLING
# count  2938.000000
# mean     12.340658
# std       3.649192
# min       0.000000
# 25%      10.300000
# 50%      12.500000
# 75%      14.600000
# max      26.135726

# %% [markdown]
# ### Data Splitting

# %%
y = pd.DataFrame(lifeTransform['STATUS'])
x = pd.DataFrame(lifeTransform.loc[:,~lifeTransform.columns.isin(['STATUS','COUNTRY'])])

x_train, x_test, y_train, y_test = train_test_split(x, y, test_size = 0.2,random_state=0) # set the seed so its reproduceable
# Check the sample sizes
print("Train Set :", x_train.shape, y_train.shape)
print("Test Set  :", x_test.shape, y_test.shape)
# Out:
# Train Set : (2350, 19) (2350, 1)
# Test Set  : (588, 19) (588, 1)

# %% [markdown]
# We first try to find out the optimum depth for the decision tree by trying different depths from 1 to 10

# %%
# Plot the trained Decision Tree
from sklearn.tree import plot_tree

for  i in range(1,11,1):
    dectree = DecisionTreeClassifier(max_depth = i)  # create the decision tree object
    dectree.fit(x_train, y_train)  
    f = plt.figure(figsize=(12,12))
    plot_tree(dectree, filled=True, rounded=True, 
          feature_names=x_train.columns, 
          class_names=["Developed","Developing"])
# Out:
# Error in callback <function flush_figures at 0x000001C279BBCDC0> (for post_execute):
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# ~\anaconda3\lib\site-packages\matplotlib_inline\backend_inline.py in flush_figures()
#     124             # ignore the tracking, just draw and close all figures
#     125             try:
# --> 126                 return show(True)
#     127             except Exception as e:
#     128                 # safely show traceback if in IPython, else raise
#
# ~\anaconda3\lib\site-packages\matplotlib_inline\backend_inline.py in show(close, block)
#      88     try:
#      89         for figure_manager in Gcf.get_all_fig_managers():
# ---> 90             display(
#      91                 figure_manager.canvas.figure,
#      92                 metadata=_fetch_figure_metadata(figure_manager.canvas.figure)
#
# ~\anaconda3\lib\site-packages\IPython\core\display.py in display(include, exclude, metadata, transient, display_id, *objs, **kwargs)
#     318             publish_display_data(data=obj, metadata=metadata, **kwargs)
#     319         else:
# --> 320             format_dict, md_dict = format(obj, include=include, exclude=exclude)
#     321             if not format_dict:
#     322                 # nothing to display (e.g. _ipython_display_ took over)
#
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in format(self, obj, include, exclude)
#     178             md = None
#     179             try:
# --> 180                 data = formatter(obj)
#     181             except:
#     182                 # FIXME: log the exception
#
# ~\anaconda3\lib\site-packages\decorator.py in fun(*args, **kw)
#     230             if not kwsyntax:
#     231                 args, kw = fix(args, kw, sig)
# --> 232             return caller(func, *(extras + args), **kw)
#     233     fun.__name__ = func.__name__
#     234     fun.__doc__ = func.__doc__
#
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in catch_format_error(method, self, *args, **kwargs)
#     222     """show traceback on failed format call"""
#     223     try:
# --> 224         r = method(self, *args, **kwargs)
#     225     except NotImplementedError:
#     226         # don't warn on NotImplementedErrors
#
# ~\anaconda3\lib\site-packages\IPython\core\formatters.py in __call__(self, obj)
#     339                 pass
#     340             else:
# --> 341                 return printer(obj)
#     342             # Finally look for special method names
#     343             method = get_real_method(obj, self.print_method)
#
# ~\anaconda3\lib\site-packages\IPython\core\pylabtools.py in print_figure(fig, fmt, bbox_inches, base64, **kwargs)
#     149         FigureCanvasBase(fig)
#     150
# --> 151     fig.canvas.print_figure(bytes_io, **kw)
#     152     data = bytes_io.getvalue()
#     153     if fmt == 'svg':
#
# ~\anaconda3\lib\site-packages\matplotlib\backend_bases.py in print_figure(self, filename, dpi, facecolor, edgecolor, orientation, format, bbox_inches, pad_inches, bbox_extra_artists, backend, **kwargs)
#    2297             if bbox_inches:
#    2298                 if bbox_inches == "tight":
# -> 2299                     bbox_inches = self.figure.get_tightbbox(
#    2300                         renderer, bbox_extra_artists=bbox_extra_artists)
#    2301                     if pad_inches is None:
#
# ~\anaconda3\lib\site-packages\matplotlib\figure.py in get_tightbbox(self, renderer, bbox_extra_artists)
#    1682
#    1683         for a in artists:
# -> 1684             bbox = a.get_tightbbox(renderer)
#    1685             if bbox is not None and (bbox.width != 0 or bbox.height != 0):
#    1686                 bb.append(bbox)
#
# ~\anaconda3\lib\site-packages\matplotlib\axes\_base.py in get_tightbbox(self, renderer, call_axes_locator, bbox_extra_artists, for_layout_only)
#    4673                     # this artist
#    4674                     continue
# -> 4675             bbox = a.get_tightbbox(renderer)
#    4676             if (bbox is not None
#    4677                     and 0 < bbox.width < np.inf
#
# ~\anaconda3\lib\site-packages\matplotlib\text.py in get_tightbbox(self, renderer)
#    2008         if not self._check_xy(renderer):
#    2009             return Bbox.null()
# -> 2010         return super().get_tightbbox(renderer)
#    2011
#    2012
#
# ~\anaconda3\lib\site-packages\matplotlib\artist.py in get_tightbbox(self, renderer)
#     353             The enclosing bounding box (in figure pixel coordinates).
#     354         """
# --> 355         bbox = self.get_window_extent(renderer)
#     356         if self.get_clip_on():
#     357             clip_box = self.get_clip_box()
#
# ~\anaconda3\lib\site-packages\matplotlib\text.py in get_window_extent(self, renderer)
#    2000
#    2001         if self.arrow_patch is not None:
# -> 2002             bboxes.append(self.arrow_patch.get_window_extent())
#    2003
#    2004         return Bbox.union(bboxes)
#
# ~\anaconda3\lib\site-packages\matplotlib\patches.py in get_window_extent(self, renderer)
#     627
#     628     def get_window_extent(self, renderer=None):
# --> 629         return self.get_path().get_extents(self.get_transform())
#     630
#     631     def _convert_xy_units(self, xy):
#
# ~\anaconda3\lib\site-packages\matplotlib\patches.py in get_path(self)
#    4444         # The path is generated in display coordinates, then converted back to
#    4445         # data coordinates.
# -> 4446         _path, fillable = self._get_path_in_displaycoord()
#    4447         if np.iterable(fillable):
#    4448             _path = Path.make_compound_path(*_path)
#
# ~\anaconda3\lib\site-packages\matplotlib\patches.py in _get_path_in_displaycoord(self)
#    4457             posB = self._convert_xy_units(self._posA_posB[1])
#    4458             (posA, posB) = self.get_transform().transform((posA, posB))
# -> 4459             _path = self.get_connectionstyle()(posA, posB,
#    4460                                                patchA=self.patchA,
#    4461                                                patchB=self.patchB,
#
# ~\anaconda3\lib\site-packages\matplotlib\patches.py in __call__(self, posA, posB, shrinkA, shrinkB, patchA, patchB)
#    2774             """
#    2775             path = self.connect(posA, posB)
# -> 2776             clipped_path = self._clip(path, patchA, patchB)
#    2777             shrunk_path = self._shrink(clipped_path, shrinkA, shrinkB)
#    2778             return shrunk_path
#
# ~\anaconda3\lib\site-packages\matplotlib\patches.py in _clip(self, path, patchA, patchB)
#    2729
#    2730                 try:
# -> 2731                     left, right = split_path_inout(path, insideA)
#    2732                 except ValueError:
#    2733                     right = path
#
# ~\anaconda3\lib\site-packages\matplotlib\bezier.py in split_path_inout(path, inside, tolerance, reorder_inout)
#     369
#     370     bp = bezier_path.reshape((-1, 2))
# --> 371     left, right = split_bezier_intersecting_with_closedpath(
#     372         bp, inside, tolerance)
#     373     if len(left) == 2:
#
# ~\anaconda3\lib\site-packages\matplotlib\bezier.py in split_bezier_intersecting_with_closedpath(bezier, inside_closedpath, tolerance)
#     332     bezier_point_at_t = bz.point_at_t
#     333
# --> 334     t0, t1 = find_bezier_t_intersecting_with_closedpath(
#     335         bezier_point_at_t, inside_closedpath, tolerance=tolerance)
#     336
#
# ~\anaconda3\lib\site-packages\matplotlib\bezier.py in find_bezier_t_intersecting_with_closedpath(bezier_point_at_t, inside_closedpath, t0, t1, tolerance)
#     168         middle_t = 0.5 * (t0 + t1)
#     169         middle = bezier_point_at_t(middle_t)
# --> 170         middle_inside = inside_closedpath(middle)
#     171
#     172         if start_inside ^ middle_inside:
#
# ~\anaconda3\lib\site-packages\matplotlib\patches.py in insideA(xy_display)
#    2726                 def insideA(xy_display):
#    2727                     xy_event = ConnectionStyle._Base.SimpleEvent(xy_display)
# -> 2728                     return patchA.contains(xy_event)[0]
#    2729
#    2730                 try:
#
# ~\anaconda3\lib\site-packages\matplotlib\patches.py in contains(self, mouseevent, radius)
#     163         else:
#     164             subpaths = [self.get_path()]
# --> 165         inside = any(
#     166             subpath.contains_point(
#     167                 (mouseevent.x, mouseevent.y), self.get_transform(), radius)
#
# ~\anaconda3\lib\site-packages\matplotlib\patches.py in <genexpr>(.0)
#     164             subpaths = [self.get_path()]
#     165         inside = any(
# --> 166             subpath.contains_point(
#     167                 (mouseevent.x, mouseevent.y), self.get_transform(), radius)
#     168             for subpath in subpaths)
#
# ~\anaconda3\lib\site-packages\matplotlib\path.py in contains_point(self, point, transform, radius)
#     529         """
#     530         if transform is not None:
# --> 531             transform = transform.frozen()
#     532         # `point_in_path` does not handle nonlinear transforms, so we
#     533         # transform the path ourselves.  If *transform* is affine, letting
#
# ~\anaconda3\lib\site-packages\matplotlib\transforms.py in frozen(self)
#    1846     def frozen(self):
#    1847         # docstring inherited
# -> 1848         return Affine2D(self.get_matrix().copy())
#    1849
#    1850     @property
#
# ~\anaconda3\lib\site-packages\matplotlib\transforms.py in __init__(self, matrix, **kwargs)
#    1912             # A bit faster than np.identity(3).
#    1913             matrix = IdentityTransform._mtx.copy()
# -> 1914         self._mtx = matrix.copy()
#    1915         self._invalid = 0
#    1916
#
# KeyboardInterrupt:

# %% [markdown]
# ### Goodness of Fit of the Model
#
# Metrics : Classification Accuracy and Confusion Matrix.

# %%
y_train_pred = dectree.predict(x_train)
y_test_pred = dectree.predict(x_test)

# %%
prev_accuracytest = 0
prev_accuracytrain = 0
for  i in range(1,11,1):
    dectree = DecisionTreeClassifier(max_depth = i)  # create the decision tree object
    dectree.fit(x_train, y_train)  
    print("Classification Decision Tree Depth =", i)
    print("Goodness of Fit of Model \tTrain Dataset")
    print("Classification Accuracy \t:", dectree.score(x_train, y_train))
    print("Difference \t\t\t:", dectree.score(x_train, y_train)-prev_accuracytrain)
    prev_accuracytrain=dectree.score(x_train, y_train)
    print()

    # Check the Goodness of Fit (on Test Data)
    print("Goodness of Fit of Model \tTest Dataset")
    #prev_accuracytest=dectree.score(x_test, y_test)-prev_accuracytest
    print("Classification Accuracy \t:", dectree.score(x_test, y_test))
    print("Difference \t\t\t:", dectree.score(x_test, y_test)-prev_accuracytest)
    prev_accuracytest=dectree.score(x_test, y_test)
    print()
    print("--------------------------------------------------")
# Out:
# Classification Decision Tree Depth = 1
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.8953191489361703
# Difference 			: 0.8953191489361703
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.8775510204081632
# Difference 			: 0.8775510204081632
#
# --------------------------------------------------
# Classification Decision Tree Depth = 2
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.9246808510638298
# Difference 			: 0.02936170212765954
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.9013605442176871
# Difference 			: 0.023809523809523836
#
# --------------------------------------------------
# Classification Decision Tree Depth = 3
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.9259574468085107
# Difference 			: 0.001276595744680864
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.9149659863945578
# Difference 			: 0.013605442176870763
#
# --------------------------------------------------
# Classification Decision Tree Depth = 4
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.9472340425531914
# Difference 			: 0.02127659574468077
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.9387755102040817
# Difference 			: 0.023809523809523836
#
# --------------------------------------------------
# Classification Decision Tree Depth = 5
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.9617021276595744
# Difference 			: 0.014468085106382977
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.9438775510204082
# Difference 			: 0.005102040816326481
#
# --------------------------------------------------
# Classification Decision Tree Depth = 6
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.9748936170212766
# Difference 			: 0.013191489361702224
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.9523809523809523
# Difference 			: 0.008503401360544172
#
# --------------------------------------------------
# Classification Decision Tree Depth = 7
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.9868085106382979
# Difference 			: 0.01191489361702125
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.9540816326530612
# Difference 			: 0.001700680272108901
#
# --------------------------------------------------
# Classification Decision Tree Depth = 8
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.9923404255319149
# Difference 			: 0.00553191489361704
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.9540816326530612
# Difference 			: 0.0
#
# --------------------------------------------------
# Classification Decision Tree Depth = 9
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.9948936170212765
# Difference 			: 0.002553191489361617
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.9540816326530612
# Difference 			: 0.0
#
# --------------------------------------------------
# Classification Decision Tree Depth = 10
# Goodness of Fit of Model 	Train Dataset
# Classification Accuracy 	: 0.997872340425532
# Difference 			: 0.0029787234042554234
#
# Goodness of Fit of Model 	Test Dataset
# Classification Accuracy 	: 0.9608843537414966
# Difference 			: 0.006802721088435382
#
# --------------------------------------------------

# %% [markdown]
# ##### After exploring, we noticed that beyond tree depth = 4, there is negligible improvement in classification accuracy of the decision tree.
# ##### Therefore, we have decided the optimum tree depth is 4

# %%
dectree = DecisionTreeClassifier(max_depth = 4)  # create the decision tree object
dectree.fit(x_train, y_train)  

f, axes = plt.subplots(1, 2, figsize=(12, 4))
sb.heatmap(confusion_matrix(y_train, y_train_pred),
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[0])
sb.heatmap(confusion_matrix(y_test, y_test_pred), 
           annot = True, fmt=".0f", annot_kws={"size": 18}, ax = axes[1])
# Out:
# <AxesSubplot:>

# %%
print("Train Data for Classification Tree")
print("Accuracy  :\t", dectree.score(x_train, y_train))
print()

# Print the Accuracy Measures from the Confusion Matrix
cmTrain = confusion_matrix(y_train, y_train_pred)
tpTrain = cmTrain[1][1] # True Positives : Y (1) predicted Y (1)
fpTrain = cmTrain[0][1] # False Positives : N (0) predicted Y (1)
tnTrain = cmTrain[0][0] # True Negatives : N (0) predicted N (0)
fnTrain = cmTrain[1][0] # False Negatives : Y (1) predicted N (0)

print("TPR Train :\t", (tpTrain/(tpTrain + fnTrain)))
print("TNR Train :\t", (tnTrain/(tnTrain + fpTrain)))
print()

print("FPR Train :\t", (fpTrain/(tnTrain + fpTrain)))
print("FNR Train :\t", (fnTrain/(tpTrain + fnTrain)))
# Out:
# Train Data for Classification Tree
# Accuracy  :	 0.9472340425531914
#
# TPR Train :	 0.9974424552429667
# TNR Train :	 1.0
#
# FPR Train :	 0.0
# FNR Train :	 0.0025575447570332483

# %%
print("Test Data for Classification Tree")
print("Accuracy  :\t", dectree.score(x_test, y_test))
print()

# Print the Accuracy Measures from the Confusion Matrix
cmTest = confusion_matrix(y_test, y_test_pred)
tpTest = cmTest[1][1] # True Positives : Y (1) predicted Y (1)
fpTest = cmTest[0][1] # False Positives : N (0) predicted Y (1)
tnTest = cmTest[0][0] # True Negatives : N (0) predicted N (0)
fnTest = cmTest[1][0] # False Negatives : Y (1) predicted N (0)

print("TPR Test :\t", (tpTest/(tpTest + fnTest)))
print("TNR Test :\t", (tnTest/(tnTest + fpTest)))
print()

print("FPR Test :\t", (fpTest/(fpTest + tnTest)))
print("FNR Test :\t", (fnTest/(fnTest + tpTest)))
# Out:
# Test Data for Classification Tree
# Accuracy  :	 0.9387755102040817
#
# TPR Test :	 0.9766454352441614
# TNR Test :	 0.8717948717948718
#
# FPR Test :	 0.1282051282051282
# FNR Test :	 0.02335456475583864

# %% [markdown]
# ### Although the accuracy we have achieved with decision tree model seems quite high, We will try alternative methods like Logistic Regression to further improve the model

# %% [markdown]
# # Logistics Regression

# %%
life_filled=pd.read_csv("dataset/life_filled.csv")
sb.scatterplot(x= life_filled["LIFE_EXPECTANCY"], y= life_filled["LIFE_EXPECTANCY"] , hue=life_filled["STATUS"])
# Out:
# <AxesSubplot:xlabel='LIFE_EXPECTANCY', ylabel='LIFE_EXPECTANCY'>

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.datasets import make_classification

# %%
LogsRegDF = pd.read_csv("dataset/life_transform.csv")
print("Data dimensions", LogsRegDF.shape)
LogsRegDF.head()
# Out:
# Data dimensions (2938, 22)
#    Unnamed: 0      COUNTRY  STATUS    YEAR  LIFE_EXPECTANCY  ADULT_MORTALITY  \
# 0           0  Afghanistan       1  2015.0         0.294686         0.802268
# 1           1  Afghanistan       1  2014.0         0.187396         0.813152
# 2           2  Afghanistan       1  2013.0         0.187396         0.809070
# 3           3  Afghanistan       1  2012.0         0.180763         0.814512
# 4           4  Afghanistan       1  2011.0         0.175788         0.818594
#
#    INFANT_DEATHS   ALCOHOL  PERCENTAGE_EXPENDITURE  HEPATITIS_B  ...  \
# 0       0.606280 -1.540089               -0.653537     0.317298  ...
# 1       0.611111 -1.540089               -0.641558     0.293245  ...
# 2       0.615942 -1.540089               -0.643161     0.309280  ...
# 3       0.623188 -1.540089               -0.617785     0.333333  ...
# 4       0.628019 -1.540089               -1.506529     0.340278  ...
#
#    UNDER_FIVE_DEATHS     POLIO  TOTAL_EXPENDITURE  DIPHTHERIA  HIV/AIDS  \
# 0           0.616162  0.006410           0.562634    0.171717       0.0
# 1           0.621212  0.127778           0.567017    0.156566       0.0
# 2           0.626263  0.150000           0.556038    0.166667       0.0
# 3           0.632997  0.177778           0.639925    0.181818       0.0
# 4           0.639731  0.183333           0.497836    0.186869       0.0
#
#         GDP  POPULATION  THINNESS_5_to_19_YEARS  \
# 0 -0.765913    0.695802                1.863475
# 1 -0.745047   -0.642920                1.881842
# 2 -0.731598    0.674292                1.896363
# 3 -0.705787   -0.011252                1.914304
# 4 -1.725140   -0.073218                1.932018
#
#    INCOME_COMPOSITION_OF_RESOURCES  SCHOOLING
# 0                         0.215278       10.1
# 1                         0.211111       10.0
# 2                         0.202778        9.9
# 3                         0.193056        9.8
# 4                         0.180556        9.5
#
# [5 rows x 22 columns]

# %% [markdown]
# ### Uni-Variate Regression

# %%
logsRegPred = pd.DataFrame(LogsRegDF[["SCHOOLING", "STATUS"]])
logsRegPred.head(n = 1000)
# Out:
#      SCHOOLING  STATUS
# 0         10.1       1
# 1         10.0       1
# 2          9.9       1
# 3          9.8       1
# 4          9.5       1
# ..         ...     ...
# 995       17.0       0
# 996       16.9       0
# 997       16.9       0
# 998       16.8       0
# 999       16.7       0
#
# [1000 rows x 2 columns]

# %%
logsRegPred.shape
# Out:
# (2938, 2)

# %%
Schooling = pd.DataFrame(LogsRegDF["SCHOOLING"])
CountryStatus = pd.DataFrame(LogsRegDF["STATUS"])

# %% [markdown]
# ## Initializing Country Status:

# %%
CountryStatus = pd.get_dummies(CountryStatus, drop_first = False)
CountryStatus['STATUS'] = 1 - CountryStatus['STATUS']
#@CountryStatus.sample(n=5)
#CountryStatus["STATUS"]  = CountryStatus["STATUS"].replace({1:0, 0:1})
CountryStatus.head
#df_dummies['A_1'] = 1 - df_dummies['A_1']
# Out:
# <bound method NDFrame.head of       STATUS
# 0          0
# 1          0
# 2          0
# 3          0
# 4          0
# ...      ...
# 2933       0
# 2934       0
# 2935       0
# 2936       0
# 2937       0
#
# [2938 rows x 1 columns]>

# %% [markdown]
# ### 1 Means Country is Considered As Developed
# ### 0 Means Country is Considered As Developing

# %%
CountryStatus.dtypes
# Out:
# STATUS    int64
# dtype: object

# %%
#colors = ['red' if CountryStatus == 1 else 'yellow']
plt.scatter(Schooling, CountryStatus,  cmap='Rainbow')
plt.xlabel ("Schooling")
plt.ylabel("Country Development Status")

plt.title('Scatter Plot of Logistic Regression (Schooling Vs Country Development Status)')
#plt.plot(Schooling, linreg.predict([["Schooling"]]), color = "green")
plt.show()

# %%
SchoolingTrain, SchoolingTest, CountryStatusTrain, CountryStatusTest = train_test_split(Schooling, CountryStatus, test_size = 0.25)

# %%
LogReg = LogisticRegression(max_iter=2938)

# %%
LogReg.fit(SchoolingTrain, CountryStatusTrain)
# Out:
# C:\Users\lotzi\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(max_iter=2938)

# %% [markdown]
# ## Predicting Country Development Status using Schooling Years of Citizen

# %%
#Try to predict citizen in a certain country with 20 years of schooling vs 2 year of schooling
x = LogReg.predict(np.array([[20]]))[0]
if x==1:
    status = "Developed"
else:
    status = "Developing"
print("citizen with 20 years schooling will most likely live in", status, "Country")

x = LogReg.predict(np.array([[2]]))[0]
if x==1:
    status = "Developed"
else:
    status = "Developing"
print("citizen with 2 years schooling will most likely live in", status, "Country")
# Out:
# citizen with 20 years schooling will most likely live in Developed Country
# citizen with 2 years schooling will most likely live in Developing Country
# C:\Users\lotzi\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(
# C:\Users\lotzi\anaconda3\lib\site-packages\sklearn\base.py:450: UserWarning: X does not have valid feature names, but LogisticRegression was fitted with feature names
#   warnings.warn(

# %%
LogReg.score(SchoolingTrain, CountryStatusTrain)
# Out:
# 0.8542896050839764

# %%
CountryStatusTestPred = LogReg.predict(SchoolingTest)

# %%
sb.heatmap(confusion_matrix(CountryStatusTest, CountryStatusTestPred), annot = True, fmt = ".0f")
# Out:
# <AxesSubplot:>

# %%
print("Test Data for Logistics Regression")
print("Accuracy  :\t", LogReg.score(SchoolingTest, CountryStatusTest))
print()

# Print the Accuracy Measures from the Confusion Matrix
cmTest = confusion_matrix(CountryStatusTest, CountryStatusTestPred)
tpTest = cmTest[1][1] # True Positives : Y (1) predicted Y (1)
fpTest = cmTest[0][1] # False Positives : N (0) predicted Y (1)
tnTest = cmTest[0][0] # True Negatives : N (0) predicted N (0)
fnTest = cmTest[1][0] # False Negatives : Y (1) predicted N (0)

print("TPR Test :\t", (tpTest/(tpTest + fnTest)))
print("TNR Test :\t", (tnTest/(tnTest + fpTest)))
print()

print("FPR Test :\t", (fpTest/(fpTest + tnTest)))
print("FNR Test :\t", (fnTest/(fnTest + tpTest)))
# Out:
# Test Data for Logistics Regression
# Accuracy  :	 0.8299319727891157
#
# TPR Test :	 0.3106060606060606
# TNR Test :	 0.9436152570480929
#
# FPR Test :	 0.05638474295190713
# FNR Test :	 0.6893939393939394

# %% [markdown]
# # Multi-Variate Logistics regression
# After finding the accuracy for the Univariate Logistic Regression using Schooling vs Country Development status is only at 0.84, we want to see if there is any positive improvements to our model if we use more variables to train and test our Country Development Status data and if the accuracy of the model will increase.
#
# Hence, we will execute a multi-variate Logistic Regression

# %%
LogsRegDF.drop(columns=LogsRegDF.columns[0],axis=1,inplace=True)
LogsRegDF.head()
# Out:
#        COUNTRY  STATUS    YEAR  LIFE_EXPECTANCY  ADULT_MORTALITY  \
# 0  Afghanistan       1  2015.0         0.294686         0.802268
# 1  Afghanistan       1  2014.0         0.187396         0.813152
# 2  Afghanistan       1  2013.0         0.187396         0.809070
# 3  Afghanistan       1  2012.0         0.180763         0.814512
# 4  Afghanistan       1  2011.0         0.175788         0.818594
#
#    INFANT_DEATHS   ALCOHOL  PERCENTAGE_EXPENDITURE  HEPATITIS_B   MEASLES  \
# 0       0.606280 -1.540089               -0.653537     0.317298  0.806913
# 1       0.611111 -1.540089               -0.641558     0.293245  0.766886
# 2       0.615942 -1.540089               -0.643161     0.309280  0.749863
# 3       0.623188 -1.540089               -0.617785     0.333333  0.883365
# 4       0.628019 -1.540089               -1.506529     0.340278  0.888946
#
#    ...  UNDER_FIVE_DEATHS     POLIO  TOTAL_EXPENDITURE  DIPHTHERIA  HIV/AIDS  \
# 0  ...           0.616162  0.006410           0.562634    0.171717       0.0
# 1  ...           0.621212  0.127778           0.567017    0.156566       0.0
# 2  ...           0.626263  0.150000           0.556038    0.166667       0.0
# 3  ...           0.632997  0.177778           0.639925    0.181818       0.0
# 4  ...           0.639731  0.183333           0.497836    0.186869       0.0
#
#         GDP  POPULATION  THINNESS_5_to_19_YEARS  \
# 0 -0.765913    0.695802                1.863475
# 1 -0.745047   -0.642920                1.881842
# 2 -0.731598    0.674292                1.896363
# 3 -0.705787   -0.011252                1.914304
# 4 -1.725140   -0.073218                1.932018
#
#    INCOME_COMPOSITION_OF_RESOURCES  SCHOOLING
# 0                         0.215278       10.1
# 1                         0.211111       10.0
# 2                         0.202778        9.9
# 3                         0.193056        9.8
# 4                         0.180556        9.5
#
# [5 rows x 21 columns]

# %%
LogsRegDF.dtypes
# Out:
# COUNTRY                             object
# STATUS                               int64
# YEAR                               float64
# LIFE_EXPECTANCY                    float64
# ADULT_MORTALITY                    float64
# INFANT_DEATHS                      float64
# ALCOHOL                            float64
# PERCENTAGE_EXPENDITURE             float64
# HEPATITIS_B                        float64
# MEASLES                            float64
# BMI                                float64
# UNDER_FIVE_DEATHS                  float64
# POLIO                              float64
# TOTAL_EXPENDITURE                  float64
# DIPHTHERIA                         float64
# HIV/AIDS                           float64
# GDP                                float64
# POPULATION                         float64
# THINNESS_5_to_19_YEARS             float64
# INCOME_COMPOSITION_OF_RESOURCES    float64
# SCHOOLING                          float64
# dtype: object

# %%
LogsRegDF['STATUS'] = 1 - LogsRegDF['STATUS']
#LogsRegDF = pd.concat([LogsRegDF, LogsRegDF_dummies], axis=1)
#LogsRegDF.drop(['STATUS'], axis=1, inplace=True)
LogsRegDF
# Out:
#           COUNTRY  STATUS    YEAR  LIFE_EXPECTANCY  ADULT_MORTALITY  \
# 0     Afghanistan       0  2015.0         0.294686         0.802268
# 1     Afghanistan       0  2014.0         0.187396         0.813152
# 2     Afghanistan       0  2013.0         0.187396         0.809070
# 3     Afghanistan       0  2012.0         0.180763         0.814512
# 4     Afghanistan       0  2011.0         0.175788         0.818594
# ...           ...     ...     ...              ...              ...
# 2933     Zimbabwe       0  2004.0         0.046784         1.000000
# 2934     Zimbabwe       0  2003.0         0.047953         0.997757
# 2935     Zimbabwe       0  2002.0         0.049708         0.248889
# 2936     Zimbabwe       0  2001.0         0.052632         0.989627
# 2937     Zimbabwe       0  2000.0         0.056725         0.983740
#
#       INFANT_DEATHS   ALCOHOL  PERCENTAGE_EXPENDITURE  HEPATITIS_B   MEASLES  \
# 0          0.606280 -1.540089               -0.653537     0.317298  0.806913
# 1          0.611111 -1.540089               -0.641558     0.293245  0.766886
# 2          0.615942 -1.540089               -0.643161     0.309280  0.749863
# 3          0.623188 -1.540089               -0.617785     0.333333  0.883365
# 4          0.628019 -1.540089               -1.506529     0.340278  0.888946
# ...             ...       ...                     ...          ...       ...
# 2933       0.484848  0.149101                1.081648     0.340278  0.547009
# 2934       0.479798  0.088457                1.061102     0.018072  0.799610
# 2935       0.474747  0.162786               -2.312958     0.375000  0.715266
# 2936       0.474747 -0.554276               -2.312958     0.395833  0.777046
# 2937       0.469697 -0.569376                0.536294     0.416667  0.822316
#
#       ...  UNDER_FIVE_DEATHS     POLIO  TOTAL_EXPENDITURE  DIPHTHERIA  \
# 0     ...           0.616162  0.006410           0.562634    0.171717
# 1     ...           0.621212  0.127778           0.567017    0.156566
# 2     ...           0.626263  0.150000           0.556038    0.166667
# 3     ...           0.632997  0.177778           0.639925    0.181818
# 4     ...           0.639731  0.183333           0.497836    0.186869
# ...   ...                ...       ...                ...         ...
# 2933  ...           0.534188  0.177778           0.321024    0.171717
# 2934  ...           0.529915  0.008547           0.161034    0.186869
# 2935  ...           0.525641  0.211111           0.163773    0.202020
# 2936  ...           0.521368  0.233333           0.059581    0.222222
# 2937  ...           0.521368  0.255556           0.313477    0.255556
#
#       HIV/AIDS       GDP  POPULATION  THINNESS_5_to_19_YEARS  \
# 0     0.000000 -0.765913    0.695802                1.863475
# 1     0.000000 -0.745047   -0.642920                1.881842
# 2     0.000000 -0.731598    0.674292                1.896363
# 3     0.000000 -0.705787   -0.011252                1.914304
# 4     0.000000 -1.725140   -0.073218                1.932018
# ...        ...       ...         ...                     ...
# 2933  0.959553 -0.876123    0.368261                1.109933
# 2934  0.966928 -0.877103    0.364611                1.166410
# 2935  0.974304 -1.768514   -0.857872               -0.981848
# 2936  0.979776 -0.793556    0.357704               -0.744249
# 2937  0.983107 -0.794540    0.353934                1.311940
#
#       INCOME_COMPOSITION_OF_RESOURCES  SCHOOLING
# 0                            0.215278       10.1
# 1                            0.211111       10.0
# 2                            0.202778        9.9
# 3                            0.193056        9.8
# 4                            0.180556        9.5
# ...                               ...        ...
# 2933                         0.115278        9.2
# 2934                         0.130556        9.5
# 2935                         0.143056       10.0
# 2936                         0.143056        9.8
# 2937                         0.152778        9.8
#
# [2938 rows x 21 columns]

# %% [markdown]
# ### 1 Means Country is Considered As Developed
# ### 0 Means Country is Considered As Developing

# %%
# Extract Response and Predictors
y = pd.DataFrame(LogsRegDF['STATUS'])
X = pd.DataFrame(LogsRegDF.loc[:,~LogsRegDF.columns.isin(['STATUS','COUNTRY'])])

# Split the Dataset into random Train and Test
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2,random_state=0) # set the seed so its reproduceable
# Check the sample sizes
print("Train Set :", X_train.shape, y_train.shape)
print("Test Set  :", X_test.shape, y_test.shape)
# Out:
# Train Set : (2350, 19) (2350, 1)
# Test Set  : (588, 19) (588, 1)

# %%
print("Shape of x ", X.shape)
y_train.size
# Out:
# Shape of x  (2938, 19)
# 2350

# %%
mymodel = LogisticRegression(max_iter = 2350)
mymodel.fit(X_train, y_train)
#print('Intercept \t: b = ', LogReg.intercept_)
#print('Coefficients \t: a = ', LogReg.coef_)
# Out:
# C:\Users\lotzi\anaconda3\lib\site-packages\sklearn\utils\validation.py:993: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# LogisticRegression(max_iter=2350)

# %%
mymodel.score(X_train, y_train)
# Out:
# 0.9251063829787234

# %%
ytrain_pred = mymodel.predict(X_train)

# %%
mymodel.score(X_train, y_train)
# Out:
# 0.9251063829787234

# %%
sb.heatmap(confusion_matrix(y_train, ytrain_pred), annot = True, fmt = ".0f")
# Out:
# <AxesSubplot:>

# %%
print("Train Data for Logistics Regression")
print("Accuracy  :\t", mymodel.score(x_train, y_train))
print()

# Print the Accuracy Measures from the Confusion Matrix
cmTrain = confusion_matrix(y_train, ytrain_pred)
tpTrain = cmTrain[1][1] # True Positives : Y (1) predicted Y (1)
fpTrain = cmTrain[0][1] # False Positives : N (0) predicted Y (1)
tnTrain = cmTrain[0][0] # True Negatives : N (0) predicted N (0)
fnTrain = cmTrain[1][0] # False Negatives : Y (1) predicted N (0)

print("TPR Train :\t", (tpTrain/(tpTrain + fnTrain)))
print("TNR Train :\t", (tnTrain/(tnTrain + fpTrain)))
print()

print("FPR Train :\t", (fpTrain/(tnTrain + fpTrain)))
print("FNR Train :\t", (fnTrain/(tpTrain + fnTrain)))
# Out:
# Train Data for Logistics Regression
# Accuracy  :	 0.9251063829787234
#
# TPR Train :	 0.7721518987341772
# TNR Train :	 0.9560102301790281
#
# FPR Train :	 0.043989769820971865
# FNR Train :	 0.22784810126582278

# %%
ytest_pred = mymodel.predict(X_test)

# %%
mymodel.score(X_test, y_test)
# Out:
# 0.923469387755102

# %%
sb.heatmap(confusion_matrix(y_test, ytest_pred), annot = True, fmt = ".1f")
# Out:
# <AxesSubplot:>

# %%
mean_squared_error(y_train, ytrain_pred)
# Out:
# 0.0748936170212766

# %%
print("Test Data for Logistics Regression")
print("Accuracy  :\t", mymodel.score(X_test, y_test))
print()

# Print the Accuracy Measures from the Confusion Matrix
cmTest = confusion_matrix(y_test, ytest_pred)
tpTest = cmTest[1][1] # True Positives : Y (1) predicted Y (1)
fpTest = cmTest[0][1] # False Positives : N (0) predicted Y (1)
tnTest = cmTest[0][0] # True Negatives : N (0) predicted N (0)
fnTest = cmTest[1][0] # False Negatives : Y (1) predicted N (0)

print("TPR Test :\t", (tpTest/(tpTest + fnTest)))
print("TNR Test :\t", (tnTest/(tnTest + fpTest)))
print()

print("FPR Test :\t", (fpTest/(fpTest + tnTest)))
print("FNR Test :\t", (fnTest/(fnTest + tpTest)))
# Out:
# Test Data for Logistics Regression
# Accuracy  :	 0.923469387755102
#
# TPR Test :	 0.7863247863247863
# TNR Test :	 0.9575371549893843
#
# FPR Test :	 0.04246284501061571
# FNR Test :	 0.21367521367521367

# %%
mean_squared_error(y_test, ytest_pred)
# Out:
# 0.07653061224489796

# %% [markdown]
# ### Based on the obsevations, Logistic Regression has achieved a similar Classification Accuracy of around 92% as compared to Binary Decision Tree. Therefore, we conclude there is not much difference between the two methods. Both can perform equally effectively at predicting the Country Development Status.
